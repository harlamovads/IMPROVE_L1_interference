# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install transformers trl wandb
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting trl
#   Downloading trl-0.8.2-py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.7/263.7 kB 2.3 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.16.6-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.2.1+cu121)
# Collecting accelerate (from trl)
#   Downloading accelerate-0.29.2-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 18.4 MB/s eta 0:00:00
# Collecting datasets (from trl)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 38.1 MB/s eta 0:00:00
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.8.3-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.45.0-py2.py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 13.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.4.0->trl)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.4.0->trl)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.4.0->trl)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.4.0->trl)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.4.0->trl)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.4.0->trl)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.4.0->trl)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->trl)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (2.0.3)
# Collecting xxhash (from datasets->trl)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 28.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->trl)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (4.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Installing collected packages: xxhash, smmap, shtab, setproctitle, sentry-sdk, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, docker-pycreds, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, gitdb, tyro, nvidia-cusolver-cu12, GitPython, wandb, datasets, accelerate, trl
# Successfully installed GitPython-3.1.43 accelerate-0.29.2 datasets-2.18.0 dill-0.3.8 docker-pycreds-0.4.0 gitdb-4.0.11 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 sentry-sdk-1.45.0 setproctitle-1.3.3 shtab-1.7.1 smmap-5.0.1 trl-0.8.2 tyro-0.8.3 wandb-0.16.6 xxhash-3.4.1

# %%
import torch
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

from transformers import pipeline, AutoTokenizer
from datasets import load_dataset

from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead
from trl.core import LengthSampler

# %%
config = PPOConfig(
    model_name="Zlovoblachko/test_L1_sent_generator",
    learning_rate=1.41e-5,
    log_with="wandb",
)

sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 16}

# %%
import wandb

wandb.init()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240412_001214-4k5ajfjy</code>
# Syncing run <strong><a href='https://wandb.ai/zlovoblachko/uncategorized/runs/4k5ajfjy' target="_blank">hopeful-energy-11</a></strong> to <a href='https://wandb.ai/zlovoblachko/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/zlovoblachko/uncategorized' target="_blank">https://wandb.ai/zlovoblachko/uncategorized</a>
#  View run at <a href='https://wandb.ai/zlovoblachko/uncategorized/runs/4k5ajfjy' target="_blank">https://wandb.ai/zlovoblachko/uncategorized/runs/4k5ajfjy</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/zlovoblachko/uncategorized/runs/4k5ajfjy?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
def build_dataset(config, dataset_name="imdb", input_min_text_length=2, input_max_text_length=8):
    """
    Build dataset for training. This builds the dataset from `load_dataset`, one should
    customize this function to train the model on its own dataset.

    Args:
        dataset_name (`str`):
            The name of the dataset to be loaded.

    Returns:
        dataloader (`torch.utils.data.DataLoader`):
            The dataloader for the dataset.
    """
    tokenizer = AutoTokenizer.from_pretrained(config.model_name)
    tokenizer.pad_token = tokenizer.eos_token
    # load imdb with datasets
    ds = load_dataset(dataset_name, split="train")
    ds = ds.remove_columns("Simultaneously")
    ds = ds.rename_columns({"Simultaneously demand is ever soaring.": "review", "Synonyms":"label"})

    input_size = LengthSampler(input_min_text_length, input_max_text_length)

    def tokenize(sample):
        sample["input_ids"] = tokenizer.encode(sample["review"])[: input_size()]
        sample["query"] = tokenizer.decode(sample["input_ids"])
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")
    return ds

# %%
dataset = build_dataset(config, "Zlovoblachko/L1_real_aug_sents")


def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/476 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/131 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/423k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/3330 [00:00<?, ? examples/s]

# %%
model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
ref_model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
tokenizer = AutoTokenizer.from_pretrained(config.model_name)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# WARNING:root:A <class 'transformers.models.gpt2.modeling_gpt2.GPT2LMHeadModel'> model is loaded from 'Zlovoblachko/test_L1_sent_generator', and no v_head weight is found. This IS expected if you are not resuming PPO training.
# WARNING:root:A <class 'transformers.models.gpt2.modeling_gpt2.GPT2LMHeadModel'> model is loaded from 'Zlovoblachko/test_L1_sent_generator', and no v_head weight is found. This IS expected if you are not resuming PPO training.

# %%
ppo_trainer = PPOTrainer(config, model, ref_model, tokenizer, dataset=dataset, data_collator=collator)
# Out:
# Finishing last run (ID:4k5ajfjy) before initializing another...
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">hopeful-energy-11</strong> at: <a href='https://wandb.ai/zlovoblachko/uncategorized/runs/4k5ajfjy' target="_blank">https://wandb.ai/zlovoblachko/uncategorized/runs/4k5ajfjy</a><br/> View project at: <a href='https://wandb.ai/zlovoblachko/uncategorized' target="_blank">https://wandb.ai/zlovoblachko/uncategorized</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240412_001214-4k5ajfjy/logs</code>
# Successfully finished last run (ID:4k5ajfjy). Initializing new run:<br/>
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240412_001305-4v5tqwv2</code>
# Syncing run <strong><a href='https://wandb.ai/zlovoblachko/trl/runs/4v5tqwv2' target="_blank">polar-serenity-10</a></strong> to <a href='https://wandb.ai/zlovoblachko/trl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/zlovoblachko/trl' target="_blank">https://wandb.ai/zlovoblachko/trl</a>
#  View run at <a href='https://wandb.ai/zlovoblachko/trl/runs/4v5tqwv2' target="_blank">https://wandb.ai/zlovoblachko/trl/runs/4v5tqwv2</a>

# %% [markdown]
# ### Word form transmission

# %%
sentiment_pipe = pipeline("text-classification", model="Zlovoblachko/L1-classifier-WFT")

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"
sentiment_pipe = pipeline("text-classification", model="Zlovoblachko/L1-classifier-WFT", device=device)

# %%
output_min_length = 5
output_max_length = 25
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


epochs = 5
for epoch in tqdm(range(epochs), "epoch: "):
    for batch in tqdm(ppo_trainer.dataloader):
        query_tensors = batch["input_ids"]
        response_tensors = []
        for query in query_tensors:
            gen_len = output_length_sampler()
            generation_kwargs["max_new_tokens"] = gen_len
            response = ppo_trainer.generate(query, **generation_kwargs)
            response_tensors.append(response.squeeze()[-gen_len:])
        batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]
        texts = [q + r for q, r in zip(batch["query"], batch["response"])]
        pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
        rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]
        stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
        ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# epoch:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   4%|▍         | 1/26 [00:21<08:49, 21.16s/it]
#   8%|▊         | 2/26 [00:40<08:04, 20.21s/it]
#  12%|█▏        | 3/26 [00:58<07:19, 19.12s/it]
#  15%|█▌        | 4/26 [01:16<06:53, 18.79s/it]
#  19%|█▉        | 5/26 [01:34<06:28, 18.48s/it]
#  23%|██▎       | 6/26 [01:52<06:03, 18.20s/it]
#  27%|██▋       | 7/26 [02:10<05:47, 18.29s/it]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#
#  31%|███       | 8/26 [02:29<05:33, 18.53s/it]
#  35%|███▍      | 9/26 [02:48<05:15, 18.58s/it]
#  38%|███▊      | 10/26 [03:07<04:56, 18.55s/it]
#  42%|████▏     | 11/26 [03:26<04:40, 18.73s/it]
#  46%|████▌     | 12/26 [03:44<04:18, 18.47s/it]
#  50%|█████     | 13/26 [04:02<04:01, 18.57s/it]
#  54%|█████▍    | 14/26 [04:22<03:45, 18.83s/it]
#  58%|█████▊    | 15/26 [04:41<03:27, 18.85s/it]
#  62%|██████▏   | 16/26 [04:58<03:04, 18.49s/it]
#  65%|██████▌   | 17/26 [05:17<02:46, 18.46s/it]
#  69%|██████▉   | 18/26 [05:35<02:27, 18.40s/it]
#  73%|███████▎  | 19/26 [05:54<02:10, 18.58s/it]
#  77%|███████▋  | 20/26 [06:12<01:50, 18.46s/it]
#  81%|████████  | 21/26 [06:32<01:33, 18.77s/it]
#  85%|████████▍ | 22/26 [06:50<01:15, 18.75s/it]
#  88%|████████▊ | 23/26 [07:09<00:56, 18.79s/it]
#  92%|█████████▏| 24/26 [07:28<00:37, 18.74s/it]
#  96%|█████████▌| 25/26 [07:47<00:18, 18.97s/it]
# 100%|██████████| 26/26 [08:07<00:00, 18.76s/it]
# epoch:  20%|██        | 1/5 [08:07<32:30, 487.67s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   4%|▍         | 1/26 [00:18<07:30, 18.03s/it]
#   8%|▊         | 2/26 [00:35<07:09, 17.90s/it]
#  12%|█▏        | 3/26 [00:54<06:57, 18.17s/it]
#  15%|█▌        | 4/26 [01:13<06:49, 18.63s/it]
#  19%|█▉        | 5/26 [01:31<06:28, 18.49s/it]
#  23%|██▎       | 6/26 [01:49<06:03, 18.16s/it]
#  27%|██▋       | 7/26 [02:07<05:47, 18.29s/it]
#  31%|███       | 8/26 [02:26<05:32, 18.48s/it]
#  35%|███▍      | 9/26 [02:45<05:13, 18.43s/it]
#  38%|███▊      | 10/26 [03:03<04:55, 18.46s/it]
#  42%|████▏     | 11/26 [03:21<04:34, 18.29s/it]
#  46%|████▌     | 12/26 [03:40<04:18, 18.50s/it]
/it]

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                            query  \
# 0                                    Recruitment
# 1                       According to this graph,
# 2                                       Overall,
# 3                                Clinical breast
# 4                                    The authors
# 5                                           Glad
# 6                         In any way, since then
# 7                    Language is the best way of
# 8                   However, drug seizures saw a
# 9   The grand jury investigation at Philadelphia
# 10                                        All in
# 11            First two pictures introduce Yemen
# 12          Firstly, approximately 44% of number
# 13                      It is not less important
# 14                                The failure to
# 15      All people should have common rights and
#
#                                     response (before)  \
# 0    reached pre-school level in only similar age ...
# 1    the amount of male workers in different count...
# 2    all metals in Kyoto, Tokyo, Japan were transp...
# 3    or developing stages help protect us from unn...
# 4    answer this many questions in various categor...
# 5                                 imd team dominateds
# 6    everybody has different and more physical 3-y...
# 7    getting skilled musicians, musicians and infl...
# 8    slight decrease in 2014 from 1990 to 2012 and...
# 9                    's Zucco mass were doomed, and a
# 10   all, we just can't forget about modern techno...
# 11   people to agriculture and transportation on f...
# 12   of teenagers got to rural school in 1976. Bes...
# 13               then getting hit with water by road,
# 14   attend classes was the one he should be more ...
# 15   status with self and big time internet. Inter...
#
#                                      response (after)  rewards (before)  \
# 0    data is deeply the chemicals which are an ess...         -1.832326
# 1                 it shows that by 2030 the number of         -1.855791
# 2    it is obvious that the unemployment rate is r...         -1.568462
# 3    opening more than 40 percent, a lot of male a...         -0.952443
# 4    argue that there is an opportunity to reduce ...         -1.638218
# 5                                 ies can be iterally          0.846196
# 6    it has not any influence on public health. It...         -2.101387
# 7    getting healthier and healthier for all, and ...         -2.072001
# 8    major increase and market rates were plummeti...         -1.206117
# 9    County level was not so positive during the p...          1.133440
# 10   all this results leads to global warming, but...         -1.851725
# 11   diverse environmental causes including declin...         -2.098678
# 12   of girls is good as this causes negative comm...         -2.094750
# 13           that it only increases the amount of air         -1.433175
# 14   use these slightly less amount of fossil fuel...         -0.924185
# 15   not suppose that such opinions can improve on...         -1.830320
#
#     rewards (after)
# 0          1.508754
# 1         -0.626631
# 2          1.657130
# 3          1.001286
# 4          0.531674
# 5         -0.229262
# 6          0.254660
# 7         -0.902893
# 8          1.722950
# 9          1.152621
# 10         1.882440
# 11        -1.361477
# 12         0.463739
# 13         1.451165
# 14         1.847775
# 15         0.917352

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -1.342496
# rewards (after)     0.704455
# dtype: float64
# median:
# rewards (before)   -1.734269
# rewards (after)     0.959319
# dtype: float64

# %%
model.save_pretrained("WFT_L1_sent_generator", push_to_hub=True)
tokenizer.save_pretrained("WFT_L1_sent_generator", push_to_hub=True)
# Out:
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# ('WFT_L1_sent_generator/tokenizer_config.json',
#  'WFT_L1_sent_generator/special_tokens_map.json',
#  'WFT_L1_sent_generator/vocab.json',
#  'WFT_L1_sent_generator/merges.txt',
#  'WFT_L1_sent_generator/added_tokens.json',
#  'WFT_L1_sent_generator/tokenizer.json')

# %% [markdown]
# ### Tense semantics

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"
sentiment_pipe = pipeline("text-classification", model="Zlovoblachko/L1-classifier-TenSem", device=device)

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %%
output_min_length = 5
output_max_length = 25
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


epochs = 5
for epoch in tqdm(range(epochs), "epoch: "):
    for batch in tqdm(ppo_trainer.dataloader):
        query_tensors = batch["input_ids"]
        response_tensors = []
        for query in query_tensors:
            gen_len = output_length_sampler()
            generation_kwargs["max_new_tokens"] = gen_len
            response = ppo_trainer.generate(query, **generation_kwargs)
            response_tensors.append(response.squeeze()[-gen_len:])
        batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]
        texts = [q + r for q, r in zip(batch["query"], batch["response"])]
        pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
        rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]
        stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
        ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# epoch:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#
#   4%|▍         | 1/26 [00:20<08:26, 20.26s/it]
#   8%|▊         | 2/26 [00:37<07:29, 18.72s/it]
#  12%|█▏        | 3/26 [00:56<07:11, 18.74s/it]
#  15%|█▌        | 4/26 [01:14<06:47, 18.53s/it]
#  19%|█▉        | 5/26 [01:34<06:40, 19.09s/it]
#  23%|██▎       | 6/26 [01:53<06:18, 18.92s/it]
#  27%|██▋       | 7/26 [02:13<06:03, 19.13s/it]
#  31%|███       | 8/26 [02:31<05:40, 18.91s/it]
#  35%|███▍      | 9/26 [02:51<05:26, 19.22s/it]
#  38%|███▊      | 10/26 [03:11<05:10, 19.39s/it]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#
#  42%|████▏     | 11/26 [03:34<05:08, 20.57s/it]
#  46%|████▌     | 12/26 [03:51<04:32, 19.46s/it]
#  50%|█████     | 13/26 [04:19<04:45, 21.96s/it]
#  54%|█████▍    | 14/26 [04:38<04:13, 21.15s/it]
#  58%|█████▊    | 15/26 [04:57<03:44, 20.40s/it]
#  62%|██████▏   | 16/26 [05:16<03:20, 20.10s/it]
#  65%|██████▌   | 17/26 [05:35<02:56, 19.66s/it]
#  69%|██████▉   | 18/26 [05:54<02:36, 19.50s/it]
#  73%|███████▎  | 19/26 [06:13<02:16, 19.46s/it]
#  77%|███████▋  | 20/26 [06:32<01:56, 19.39s/it]
#  81%|████████  | 21/26 [06:52<01:37, 19.44s/it]
#  85%|████████▍ | 22/26 [07:12<01:18, 19.62s/it]
#  88%|████████▊ | 23/26 [07:33<00:59, 19.96s/it]
#  92%|█████████▏| 24/26 [07:51<00:38, 19.43s/it]
#  96%|█████████▌| 25/26 [08:11<00:19, 19.64s/it]
# 100%|██████████| 26/26 [08:31<00:00, 19.66s/it]
# epoch:  20%|██        | 1/5 [08:31<34:04, 511.20s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   4%|▍         | 1/26 [00:19<08:14, 19.77s/it]
#   8%|▊         | 2/26 [00:39<07:53, 19.71s/it]
#  12%|█▏        | 3/26 [00:57<07:16, 18.99s/it]
#  15%|█▌        | 4/26 [01:16<06:55, 18.88s/it]
#  19%|█▉        | 5/26 [01:34<06:31, 18.65s/it]
#  23%|██▎       | 6/26 [01:52<06:05, 18.26s/it]
#  27%|██▋       | 7/26 [02:10<05:47, 18.29s/it]
#  31%|███       | 8/26 [02:29<05:35, 18.62s/it]
#  35%|███▍      | 9/26 [02:48<05:17, 18.69s/it]
#  38%|███▊      | 10/26 [03:07<05:01, 18.83s/it]
#  42%|████▏     | 11/26 [03:25<04:38, 18.58s/it]
#  46%|████▌     | 12/26 [03:44<04:20, 18.60s/it]
#  50%|█████     | 13/26 [04:03<04:03, 18.73s/it]
#  54%|█████▍    | 14/26 [04:20<03:40, 18.34s/it]
/it]

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                               query  \
# 0                                 At the same time,
# 1                       In modern world our life is
# 2                    Some people are confident that
# 3                         Here is an imaginary tale
# 4              Public college tuition has jumped 33
# 5                                         A variety
# 6                      In Germany, China and the UK
# 7               Also people have different taste in
# 8                     By 2002 mobile calls achieved
# 9              UCI categories are categories of age
# 10                      Under this approach, direct
# 11  The policy has already accomplished significant
# 12                                For example, from
# 13                  That study included both female
# 14                               Just like in 2014,
# 15                                     Samsung soar
#
#                                     response (before)  \
# 0    children not from school can have not underst...
# 1    simiently one of the main problems that must ...
# 2             sciences which can help to a conclusion
# 3    of international pirate parties and why the p...
# 4    percent to £65 millions. Also tuition is only...
# 5    of shops provide the reverse course. I would ...
# 6    have two percent increase at %125? i.e., Japa...
# 7    different languages, some travelling by road ...
# 8               about 60% growth. These were up to 15
# 9   , faculty and what kinds of people support eac...
# 10   a female student to higher education and star...
# 11    changes while stabilization is an environmental
# 12   the countries where unemployment started in 9...
# 13   and male teenagers over the period roughly to...
# 14   China just 2 times bigger than being by rail,...
# 15   from $3.7 billion in 1985 to $15 billion in 2...
#
#                                      response (after)  rewards (before)  \
# 0    in Italy the trend was slightly abandon in 20...         -0.785985
# 1    less stable and in a different temps in 2014 ...         -1.751107
# 2    globalization will improve the statistic in 2015         -2.140757
# 3    in Japan in 2000, in 2030 and in 2050 years t...         -1.037005
# 4   ,1 percent in 2014 and 2015, while the number ...         -0.230313
# 5    of health issues have developed from 2012 to ...         -1.706560
# 6    both have thousands of people in 1998 in 1979...          1.694651
# 7    2012 than 1995, in comparison with UK except ...         -0.960485
# 8    the highest proportionly in Africa. While in ...          1.043935
# 9    in 1940 or later between 1940 and 1970. In 19...         -0.720919
# 10   actual Air route in the year 2018 is substant...         -0.590793
# 11                  number in the in 2000 demographic         -2.145741
# 12           1990's until 2030 it was 26 per cent. in          1.673497
# 13   and male unemployment rate in 2013. It is sho...          1.305445
# 14   the percentage of in Africa was 56%.ly, in La...          1.411000
# 15   by 65% in 1927, falling way in 1940 and then ...          1.249346
#
#     rewards (after)
# 0          1.823884
# 1          1.762096
# 2          0.994750
# 3          1.452268
# 4          1.508732
# 5          1.580844
# 6          1.804090
# 7          1.831349
# 8          1.669698
# 9          1.721218
# 10         1.754817
# 11         0.474085
# 12         1.433158
# 13         1.768651
# 14         1.701499
# 15         1.599353

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -0.230737
# rewards (after)     1.555031
# dtype: float64
# median:
# rewards (before)   -0.655856
# rewards (after)     1.685598
# dtype: float64

# %%
model.save_pretrained("TenSem_L1_sent_generator", push_to_hub=True)
tokenizer.save_pretrained("TenSem_L1_sent_generator", push_to_hub=True)
# Out:
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# ('TenSem_L1_sent_generator/tokenizer_config.json',
#  'TenSem_L1_sent_generator/special_tokens_map.json',
#  'TenSem_L1_sent_generator/vocab.json',
#  'TenSem_L1_sent_generator/merges.txt',
#  'TenSem_L1_sent_generator/added_tokens.json',
#  'TenSem_L1_sent_generator/tokenizer.json')

# %% [markdown]
# ### Synonyms

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"
sentiment_pipe = pipeline("text-classification", model="Zlovoblachko/L1-classifier-Synonyms", device=device)
# Out:
# config.json:   0%|          | 0.00/740 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/669k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %%
output_min_length = 5
output_max_length = 25
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


epochs = 5
for epoch in tqdm(range(epochs), "epoch: "):
    for batch in tqdm(ppo_trainer.dataloader):
        query_tensors = batch["input_ids"]
        response_tensors = []
        for query in query_tensors:
            gen_len = output_length_sampler()
            generation_kwargs["max_new_tokens"] = gen_len
            response = ppo_trainer.generate(query, **generation_kwargs)
            response_tensors.append(response.squeeze()[-gen_len:])
        batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]
        texts = [q + r for q, r in zip(batch["query"], batch["response"])]
        pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
        rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]
        stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
        ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# epoch:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#
#   4%|▍         | 1/26 [00:20<08:41, 20.85s/it]
#   8%|▊         | 2/26 [00:40<08:03, 20.13s/it]
#  12%|█▏        | 3/26 [00:59<07:34, 19.77s/it]
#  15%|█▌        | 4/26 [01:18<07:04, 19.31s/it]
#  19%|█▉        | 5/26 [01:38<06:48, 19.45s/it]
#  23%|██▎       | 6/26 [01:58<06:32, 19.63s/it]
#  27%|██▋       | 7/26 [02:17<06:09, 19.44s/it]
#  31%|███       | 8/26 [02:34<05:39, 18.88s/it]
#  35%|███▍      | 9/26 [02:52<05:14, 18.50s/it]
#  38%|███▊      | 10/26 [03:11<04:59, 18.69s/it]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#
#  42%|████▏     | 11/26 [03:31<04:47, 19.18s/it]
#  46%|████▌     | 12/26 [03:51<04:29, 19.28s/it]
#  50%|█████     | 13/26 [04:11<04:14, 19.57s/it]
#  54%|█████▍    | 14/26 [04:30<03:52, 19.36s/it]
#  58%|█████▊    | 15/26 [04:50<03:34, 19.48s/it]
#  62%|██████▏   | 16/26 [05:09<03:14, 19.45s/it]
#  65%|██████▌   | 17/26 [05:29<02:56, 19.65s/it]
#  69%|██████▉   | 18/26 [05:49<02:37, 19.65s/it]
#  73%|███████▎  | 19/26 [06:07<02:14, 19.25s/it]
#  77%|███████▋  | 20/26 [06:26<01:54, 19.13s/it]
#  81%|████████  | 21/26 [06:45<01:35, 19.02s/it]
#  85%|████████▍ | 22/26 [07:04<01:16, 19.10s/it]
#  88%|████████▊ | 23/26 [07:24<00:57, 19.30s/it]
#  92%|█████████▏| 24/26 [07:43<00:38, 19.35s/it]
#  96%|█████████▌| 25/26 [08:03<00:19, 19.37s/it]
# 100%|██████████| 26/26 [08:22<00:00, 19.31s/it]
# epoch:  20%|██        | 1/5 [08:22<33:28, 502.16s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   4%|▍         | 1/26 [00:19<08:07, 19.52s/it]
#   8%|▊         | 2/26 [00:39<07:50, 19.59s/it]
#  12%|█▏        | 3/26 [00:58<07:27, 19.45s/it]
#  15%|█▌        | 4/26 [01:17<07:07, 19.45s/it]
#  19%|█▉        | 5/26 [01:36<06:43, 19.21s/it]
#  23%|██▎       | 6/26 [01:55<06:24, 19.24s/it]
#  27%|██▋       | 7/26 [02:17<06:20, 20.02s/it]
#  31%|███       | 8/26 [02:36<05:54, 19.71s/it]
#  35%|███▍      | 9/26 [02:54<05:27, 19.26s/it]
#  38%|███▊      | 10/26 [03:14<05:11, 19.48s/it]
#  42%|████▏     | 11/26 [03:34<04:54, 19.60s/it]
#  46%|████▌     | 12/26 [03:54<04:34, 19.57s/it]
#  50%|█████     | 13/26 [04:13<04:14, 19.57s/it]
/it]

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                 query  \
# 0      Some crews promote a person to
# 1               By 2006 sales were $4
# 2        So why is texting growing in
# 3                          A possible
# 4                         All in all,
# 5                          They begin
# 6                            This was
# 7        This country had some similu
# 8      Moreover, it makes us overlook
# 9                  Statistica data of
# 10       They were extremely low paid
# 11      That is a declining of 42 per
# 12               Citizen activism has
# 13                               Peak
# 14  Next to the Africa be Middle East
# 15           The estimated cost is €3
#
#                                     response (before)  \
# 0          create a new creations. The idea of design
# 1    billion and had popularity among a stands lik...
# 2      such way become more popular than social calls
# 3    solution to this problem is not to create an ...
# 4                      the EU spends a lot. Worldwide
# 5    with in the 11th point, but the ones in the b...
# 6          a time of great finality - it was suddenly
# 7   ent small population while its changes in outl...
# 8                         impossible or goes too far.
# 9    town is growing percent of people from the ag...
# 10   and everyone who did it with money increased ...
# 11                        cent for the period from 10
# 12   a good impact on governments and environmenta...
# 13   In amount of manufactured goods grow the increas
# 14      and Latin America allX there were more than 3
# 15   billion. However, each of the remaining world...
#
#                                      response (after)  rewards (before)  \
# 0            a sport because of the trust in the fans          0.673985
# 1       millions more than state goods for free (more         -1.036358
# 2                   all the time and so often, people         -0.014280
# 3    reason is the government, as one can notice, ...          0.887826
# 4                        I had problems with avatars.          0.061614
# 5    an aades to reach results. The students will ...         -0.462678
# 6    a quick lesson and was given because mankind ...         -0.204435
# 7   ulliham which are air travel. it remained acti...         -0.494473
# 8                     the fact that some people think          0.934987
# 9    young people is also relatively really contra...         -0.960907
# 10    people, if you make them work. I would say that          0.725368
# 11                           cent and is only half or         -0.961892
# 12   a slightly higher importance than that of org...          0.218253
# 13              that's something to close down. Is it         -0.858591
# 14       and life expectancy will 100 per cent. I can         -0.952398
# 15         billion, but it is less than the other way         -0.549237
#
#     rewards (after)
# 0          0.732858
# 1         -0.928639
# 2          0.514440
# 3          0.683454
# 4         -0.396590
# 5          0.592117
# 6          0.692657
# 7         -0.536687
# 8          0.920209
# 9         -0.398864
# 10         0.877345
# 11        -0.969796
# 12         0.629539
# 13         0.054298
# 14        -0.558991
# 15        -0.579724

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -0.187076
# rewards (after)     0.082977
# dtype: float64
# median:
# rewards (before)   -0.333556
# rewards (after)     0.284369
# dtype: float64

# %%
model.save_pretrained("Synonyms_L1_sent_generator", push_to_hub=True)
tokenizer.save_pretrained("Synonyms_L1_sent_generator", push_to_hub=True)
# Out:
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# ('Synonyms_L1_sent_generator/tokenizer_config.json',
#  'Synonyms_L1_sent_generator/special_tokens_map.json',
#  'Synonyms_L1_sent_generator/vocab.json',
#  'Synonyms_L1_sent_generator/merges.txt',
#  'Synonyms_L1_sent_generator/added_tokens.json',
#  'Synonyms_L1_sent_generator/tokenizer.json')

# %% [markdown]
# ### Copying expression

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"
sentiment_pipe = pipeline("text-classification", model="Zlovoblachko/L1-classifier-CopExp", device=device)
# Out:
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/669k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %%
output_min_length = 5
output_max_length = 25
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


epochs = 5
for epoch in tqdm(range(epochs), "epoch: "):
    for batch in tqdm(ppo_trainer.dataloader):
        query_tensors = batch["input_ids"]
        response_tensors = []
        for query in query_tensors:
            gen_len = output_length_sampler()
            generation_kwargs["max_new_tokens"] = gen_len
            response = ppo_trainer.generate(query, **generation_kwargs)
            response_tensors.append(response.squeeze()[-gen_len:])
        batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]
        texts = [q + r for q, r in zip(batch["query"], batch["response"])]
        pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
        rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]
        stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
        ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# epoch:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
#
#   4%|▍         | 1/26 [00:19<08:03, 19.33s/it]
#   8%|▊         | 2/26 [00:38<07:39, 19.14s/it]
#  12%|█▏        | 3/26 [00:57<07:20, 19.17s/it]
#  15%|█▌        | 4/26 [01:16<07:02, 19.20s/it]
#  19%|█▉        | 5/26 [01:35<06:37, 18.95s/it]
#  23%|██▎       | 6/26 [01:55<06:24, 19.25s/it]
#  27%|██▋       | 7/26 [02:13<06:00, 18.95s/it]
#  31%|███       | 8/26 [02:34<05:51, 19.52s/it]
#  35%|███▍      | 9/26 [02:53<05:29, 19.38s/it]
#  38%|███▊      | 10/26 [03:13<05:13, 19.62s/it]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#
#  42%|████▏     | 11/26 [03:32<04:52, 19.48s/it]
#  46%|████▌     | 12/26 [03:52<04:33, 19.51s/it]
#  50%|█████     | 13/26 [04:12<04:16, 19.75s/it]
#  54%|█████▍    | 14/26 [04:30<03:52, 19.36s/it]
#  58%|█████▊    | 15/26 [04:48<03:26, 18.81s/it]
#  62%|██████▏   | 16/26 [05:06<03:07, 18.72s/it]
#  65%|██████▌   | 17/26 [05:26<02:50, 18.92s/it]
#  69%|██████▉   | 18/26 [05:45<02:32, 19.04s/it]
#  73%|███████▎  | 19/26 [06:04<02:13, 19.02s/it]
#  77%|███████▋  | 20/26 [06:23<01:54, 19.09s/it]
#  81%|████████  | 21/26 [06:42<01:35, 19.00s/it]
#  85%|████████▍ | 22/26 [07:02<01:16, 19.13s/it]
#  88%|████████▊ | 23/26 [07:20<00:57, 19.02s/it]
#  92%|█████████▏| 24/26 [07:40<00:38, 19.10s/it]
#  96%|█████████▌| 25/26 [08:00<00:19, 19.54s/it]
# 100%|██████████| 26/26 [08:20<00:00, 19.26s/it]
# epoch:  20%|██        | 1/5 [08:20<33:22, 500.70s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   4%|▍         | 1/26 [00:18<07:40, 18.44s/it]
#   8%|▊         | 2/26 [00:37<07:37, 19.06s/it]
#  12%|█▏        | 3/26 [00:57<07:21, 19.19s/it]
#  15%|█▌        | 4/26 [01:17<07:09, 19.52s/it]
#  19%|█▉        | 5/26 [01:36<06:49, 19.52s/it]
#  23%|██▎       | 6/26 [01:56<06:29, 19.49s/it]
#  27%|██▋       | 7/26 [02:15<06:05, 19.26s/it]
#  31%|███       | 8/26 [02:34<05:49, 19.40s/it]
#  35%|███▍      | 9/26 [02:52<05:18, 18.73s/it]
#  38%|███▊      | 10/26 [03:11<05:01, 18.86s/it]
#  42%|████▏     | 11/26 [03:30<04:44, 18.98s/it]
#  46%|████▌     | 12/26 [03:49<04:27, 19.09s/it]
#  50%|█████     | 13/26 [04:09<04:11, 19.33s/it]
#  54%|█████▍    | 14/26 [04:28<03:48, 19.08s/it]
#  58%|█████▊    | 15/26 [04:47<03:30, 19.14s/it]
#  62%|██████▏   | 16/26 [05:06<03:12, 19.25s/it]
/it]

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                           query  \
# 0                  This concentration continued
# 1          The express who live in glass houses
# 2      The arena of relationships is intolerant
# 3             One should not forget, that there
# 4                                        I don�
# 5                     They can also give use in
# 6                  The given chart compares the
# 7                            In Germany in both
# 8                     Simultaneously, the datas
# 9                                       Obesity
# 10  This was quite narrow, especially comparing
# 11                                     The same
# 12                             Lack of exercise
# 13           After this, the line of proportion
# 14                       Testimonials financing
# 15                       At the same time, this
#
#                                     response (before)  \
# 0    to decline in two years and amounted to 14% i...
# 1    with electricity only rises from 60,1 to 90,3...
# 2   ... so it is necessary to take measures to red...
# 3                         is a real way to gain chann
# 4   �t know exactly why. I am not unready to reall...
# 5    family, hobby or services, eat of modern gadg...
# 6    information about European Union situation in 12
# 7    sexes is kind and universities achieve someth...
# 8   il sent by East Asia in 2010 show a significan...
# 9                     is the main cause of overweight
# 10    in second place with 1970, where reached 12,3%.
# 11   level of temps. Japan exceeded the level of t...
# 12   would solve obesity problem because some peop...
# 13   in 2012 lost about 11 millions more per year....
# 14   fashion companies is unusually tolerant to su...
# 15   rise in age do not do anything to decrease th...
#
#                                      response (after)  rewards (before)  \
# 0    to be stable very last stable from 17% to 25 ...          0.165070
# 1    are not people of all ages, but the retiremen...          0.946890
# 2    to everyone's eyes and the event is happening...         -0.409440
# 3                are all kinds of people who give the          0.725937
# 4   �t want to do this thing. I imagine, because t...          0.681704
# 5    nervous space muscles that we pick. Mainly th...          0.674888
# 6     populations of this group aged category outside         -0.589846
# 7    genders people need also help, for example, t...          0.000770
# 8   endant of every EU people will take part in th...         -1.826002
# 9                           is a main issue of people         -1.240512
# 10   to almost all of us from the same age group o...          0.288795
# 11   situation with work is developed through ever...         -1.422264
# 12            (if you can not afford to do everything          0.467401
# 13   of population you changes from 20 - 25% of po...         -0.328150
# 14   put us in: not only is Antespray equal level ...         -0.663102
# 15   person will seriously think it will be stimul...          0.424282
#
#     rewards (after)
# 0          1.109349
# 1          1.087210
# 2          1.137671
# 3          1.158632
# 4          0.973140
# 5          0.660787
# 6         -0.383683
# 7          0.846695
# 8         -0.134454
# 9          0.112863
# 10         1.281623
# 11         0.972014
# 12         0.080513
# 13         1.287906
# 14         0.814711
# 15         1.224762

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -0.131474
# rewards (after)     0.764359
# dtype: float64
# median:
# rewards (before)    0.082920
# rewards (after)     0.972577
# dtype: float64

# %%
model.save_pretrained("CopExp_L1_sent_generator", push_to_hub=True)
tokenizer.save_pretrained("CopExp_L1_sent_generator", push_to_hub=True)
# Out:
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# ('CopExp_L1_sent_generator/tokenizer_config.json',
#  'CopExp_L1_sent_generator/special_tokens_map.json',
#  'CopExp_L1_sent_generator/vocab.json',
#  'CopExp_L1_sent_generator/merges.txt',
#  'CopExp_L1_sent_generator/added_tokens.json',
#  'CopExp_L1_sent_generator/tokenizer.json')

# %% [markdown]
# ### Transliteration

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"
sentiment_pipe = pipeline("text-classification", model="Zlovoblachko/L1-classifier-Transliteration", device=device)
# Out:
# config.json:   0%|          | 0.00/764 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/669k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %%
output_min_length = 5
output_max_length = 25
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


epochs = 5
for epoch in tqdm(range(epochs), "epoch: "):
    for batch in tqdm(ppo_trainer.dataloader):
        query_tensors = batch["input_ids"]
        response_tensors = []
        for query in query_tensors:
            gen_len = output_length_sampler()
            generation_kwargs["max_new_tokens"] = gen_len
            response = ppo_trainer.generate(query, **generation_kwargs)
            response_tensors.append(response.squeeze()[-gen_len:])
        batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]
#  42%|████▏     | 11/26 [03:17<04:31, 18.10s/it]
#  46%|████▌     | 12/26 [03:35<04:14, 18.15s/it]
#  50%|█████     | 13/26 [03:53<03:52, 17.87s/it]
#  54%|█████▍    | 14/26 [04:11<03:35, 17.98s/it]
#  58%|█████▊    | 15/26 [04:29<03:18, 18.02s/it]
#  62%|██████▏   | 16/26 [04:47<02:59, 17.96s/it]
#  65%|██████▌   | 17/26 [05:06<02:43, 18.18s/it]
#  69%|██████▉   | 18/26 [05:23<02:24, 18.02s/it]
#  73%|███████▎  | 19/26 [05:41<02:06, 18.07s/it]
#  77%|███████▋  | 20/26 [05:59<01:46, 17.81s/it]
#  81%|████████  | 21/26 [06:17<01:29, 17.92s/it]
#  85%|████████▍ | 22/26 [06:35<01:12, 18.03s/it]
#  88%|████████▊ | 23/26 [06:53<00:54, 18.04s/it]
#  92%|█████████▏| 24/26 [07:11<00:36, 18.07s/it]
#  96%|█████████▌| 25/26 [07:30<00:18, 18.30s/it]
# 100%|██████████| 26/26 [07:48<00:00, 18.01s/it]
# epoch:  80%|████████  | 4/5 [31:23<07:50, 470.10s/it]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   4%|▍         | 1/26 [00:18<07:36, 18.28s/it]
#   8%|▊         | 2/26 [00:36<07:17, 18.21s/it]
#  12%|█▏        | 3/26 [00:54<06:57, 18.15s/it]
#  15%|█▌        | 4/26 [01:13<06:46, 18.48s/it]
#  19%|█▉        | 5/26 [01:31<06:23, 18.28s/it]
#  23%|██▎       | 6/26 [01:49<06:01, 18.10s/it]
#  27%|██▋       | 7/26 [02:07<05:44, 18.11s/it]
#  31%|███       | 8/26 [02:25<05:24, 18.05s/it]
#  35%|███▍      | 9/26 [02:43<05:07, 18.08s/it]
#  38%|███▊      | 10/26 [03:02<04:52, 18.26s/it]
#  42%|████▏     | 11/26 [03:20<04:37, 18.47s/it]
#  46%|████▌     | 12/26 [03:39<04:20, 18.60s/it]
#  50%|█████     | 13/26 [03:57<03:57, 18.30s/it]
#  54%|█████▍    | 14/26 [04:14<03:35, 17.97s/it]
#  58%|█████▊    | 15/26 [04:32<03:17, 17.99s/it]
#  62%|██████▏   | 16/26 [04:51<03:00, 18.08s/it]
#  65%|██████▌   | 17/26 [05:08<02:42, 18.00s/it]
#  69%|██████▉   | 18/26 [05:27<02:24, 18.12s/it]
#  73%|███████▎  | 19/26 [05:44<02:05, 17.96s/it]
#  77%|███████▋  | 20/26 [06:02<01:47, 17.98s/it]
#  81%|████████  | 21/26 [06:19<01:28, 17.62s/it]
#  85%|████████▍ | 22/26 [06:37<01:10, 17.60s/it]
#  88%|████████▊ | 23/26 [06:55<00:53, 17.75s/it]
#  92%|█████████▏| 24/26 [07:13<00:35, 17.85s/it]
#  96%|█████████▌| 25/26 [07:31<00:18, 18.05s/it]
# 100%|██████████| 26/26 [07:50<00:00, 18.08s/it]
# epoch: 100%|██████████| 5/5 [39:13<00:00, 470.74s/it]

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                           query  \
# 0                          Some crews promote a
# 1                          By 2006 sales were $
# 2                                     So why is
# 3                             A possible way to
# 4                                        All in
# 5                           They begin from 10%
# 6                         This was using fabric
# 7                              This country had
# 8                            Moreover, it makes
# 9                        Statistica data of all
# 10                          They were extremely
# 11                          That is a declining
# 12                         Citizen activism has
# 13  Peak blood concentration is achieved within
# 14            Next to the Africa be Middle East
# 15                           The estimated cost
#
#                                     response (before)  \
# 0    fashion among people who are interested to be...
# 1              10 billion for the was in Italy then $
# 2     there a problem of spreading newborn amounts of
# 3    try this approach can be to create some kind ...
# 4              all, everything is about loving person
# 5    to 20%. The amount of children less than thei...
# 6   ine and there are definitely more economical w...
# 7    to become like a part of the normalisation of...
# 8                       sense of sharing high-quality
# 9    the years shows an increasing amount of child...
# 10   fortunate, because in the 1990 and the 90s th...
# 11                       trend in the whole sphere of
# 12   a big influence on people's education, as bot...
# 13       a half-year after reaching a almost doubling
# 14   was the tendency to win, while Eastern Europe...
# 15   of new building will be the highest worldwide...
#
#                                      response (after)  rewards (before)  \
# 0    lot of cigarettes with electronic gadgets, wh...         -0.522784
# 1                         3 try piece, enjoy by femur         -1.883240
# 2        this explanation why rails do not remain unp         -1.719967
# 3         behave is as aurop style. But not studly pl         -0.776999
# 4                      all imminently the use results         -1.409599
# 5                    to 15% in Isci (Ebutsk and Benik         -2.024133
# 6           ae that scarn surveces robbers and threat          1.810877
# 7       important influence eorfnes or socol afscistd         -1.069164
# 8                                 us consolciven that         -1.064636
# 9          kindergard a garantfull learning that taim         -0.815087
# 10        comfere when quith that women get quint est         -2.100701
# 11                             centre, but the undiqu         -2.095918
# 12   a huge aegl and among the important part of d...         -0.973590
# 13                          dikte on dicger to square         -2.076620
# 14                      Dothurohnan obtrise reaches a         -1.500797
# 15            of buyt fabrics and galignments is what         -1.826260
#
#     rewards (after)
# 0          0.740069
# 1          1.228231
# 2         -1.363717
# 3          2.240878
# 4         -2.011396
# 5          1.670215
# 6          2.293106
# 7          2.200510
# 8          0.685943
# 9          2.354837
# 10         1.666396
# 11         0.911601
# 12         1.807317
# 13         0.705886
# 14         2.141429
# 15         2.288199

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -1.253039
# rewards (after)     1.222469
# dtype: float64
# median:
# rewards (before)   -1.455198
# rewards (after)     1.668306
# dtype: float64

# %%
model.save_pretrained("Transliteration_L1_sent_generator", push_to_hub=True)
tokenizer.save_pretrained("Transliteration_L1_sent_generator", push_to_hub=True)
# Out:
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# ('Transliteration_L1_sent_generator/tokenizer_config.json',
#  'Transliteration_L1_sent_generator/special_tokens_map.json',
#  'Transliteration_L1_sent_generator/vocab.json',
#  'Transliteration_L1_sent_generator/merges.txt',
#  'Transliteration_L1_sent_generator/added_tokens.json',
#  'Transliteration_L1_sent_generator/tokenizer.json')
